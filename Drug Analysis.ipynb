# %%
import pandas as pd

# %%
data = pd.read_csv('math_score_data.csv')

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.describe()
# Out:
#        Time_Delay_in_Minutes   LSD_ppm  Avg_Math_Test_Score
# count               7.000000  7.000000             7.000000
# mean              135.714286  4.332857            50.087143
# std               172.347241  1.935413            18.610854
# min                 5.000000  1.170000            29.970000
# 25%                22.500000  3.115000            35.195000
# 50%                60.000000  4.690000            45.650000
# 75%               180.000000  5.915000            62.835000
# max               480.000000  6.410000            78.930000

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
from pandas import DataFrame as df

# %%
x= df(data,columns=['LSD_ppm'])

# %%
y=df(data,columns=['Avg_Math_Test_Score'])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.show()

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
print(x)
# Out:
#    LSD_ppm
# 0     1.17
# 1     2.97
# 2     3.26
# 3     4.69
# 4     5.83
# 5     6.00
# 6     6.41

# %%
print(y)
# Out:
#    Avg_Math_Test_Score
# 0                78.93
# 1                58.20
# 2                67.47
# 3                37.47
# 4                45.65
# 5                32.92
# 6                29.97

# %%
plt.figure(figsize=(10,6))

# %%
plt.scatter(x,y,alpha= 0.9)
plt.title('Analysis Drug injection Vs PPM')
plt.xlabel('Avg of score')
plt.ylabel('Amount of drung/PPM')
# Out:
# Text(0, 0.5, 'Amount of drung/PPM')

# %%
plt.ylim(0,100)
plt.xlim(0,10)
plt.show()

# %%
plt.scatter(x,y,alpha= 0.9)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(x,y)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([[-9.00946642]])

# %%
plt.scatter(x,y,alpha= 0.9)
plt.title('Analysis Drug injection Vs PPM')
plt.xlabel('Avg of score')
plt.ylabel('Amount of drug in PPM')
plt.plot(x,regression.predict(x),color= 'green', linewidth=5)

# %%
regression.score(x,y)
# Out:
# 0.8778349707775888
